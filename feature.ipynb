# %%
from inference.backward_chaining import *
from cnf.build_kb import generate_kb
from horn_clauses.build_horn_kb import build_kb
from utils.parse import parse_input_file
from benchmark.benchmark_all_test import benchmark_one
import sys
import os
import pandas as pd

# %% [markdown]
# # Ground KB

# %%
data = parse_input_file("input/input_01.txt")
kb = generate_kb(data)
clauses = kb.conjuncts
print(f"Tổng số mệnh đề (clauses): {len(clauses)}")
print(f"Tổng số biến (symbols): {len(kb.symbols())}")
print("-" * 50)

# 3. In chi tiết từng mệnh đề
for i, clause in enumerate(clauses):
# .formula() giúp hiển thị ký hiệu logic ~, |, & thay vì tên object
    print(f"Clause {i:03d}: {clause.formula()}")
            
print(f"{'='*25} END KB DEBUG {'='*25}\n")
# Out:
# Tổng số mệnh đề (clauses): 11
# Tổng số biến (symbols): 31
# --------------------------------------------------
# Clause 000: ((Val_1_1_1) ∨ (Val_1_1_2) ∨ (Val_1_1_3)) ∧ ((Val_1_2_1) ∨ (Val_1_2_2) ∨ (Val_1_2_3)) ∧ ((Val_1_3_1) ∨ (Val_1_3_2) ∨ (Val_1_3_3)) ∧ ((Val_2_1_1) ∨ (Val_2_1_2) ∨ (Val_2_1_3)) ∧ ((Val_2_2_1) ∨ (Val_2_2_2) ∨ (Val_2_2_3)) ∧ ((Val_2_3_1) ∨ (Val_2_3_2) ∨ (Val_2_3_3)) ∧ ((Val_3_1_1) ∨ (Val_3_1_2) ∨ (Val_3_1_3)) ∧ ((Val_3_2_1) ∨ (Val_3_2_2) ∨ (Val_3_2_3)) ∧ ((Val_3_3_1) ∨ (Val_3_3_2) ∨ (Val_3_3_3))
# Clause 001: ((¬(Val_1_1_1)) ∨ (¬(Val_1_1_2))) ∧ ((¬(Val_1_1_1)) ∨ (¬(Val_1_1_3))) ∧ ((¬(Val_1_1_2)) ∨ (¬(Val_1_1_3))) ∧ ((¬(Val_1_2_1)) ∨ (¬(Val_1_2_2))) ∧ ((¬(Val_1_2_1)) ∨ (¬(Val_1_2_3))) ∧ ((¬(Val_1_2_2)) ∨ (¬(Val_1_2_3))) ∧ ((¬(Val_1_3_1)) ∨ (¬(Val_1_3_2))) ∧ ((¬(Val_1_3_1)) ∨ (¬(Val_1_3_3))) ∧ ((¬(Val_1_3_2)) ∨ (¬(Val_1_3_3))) ∧ ((¬(Val_2_1_1)) ∨ (¬(Val_2_1_2))) ∧ ((¬(Val_2_1_1)) ∨ (¬(Val_2_1_3))) ∧ ((¬(Val_2_1_2)) ∨ (¬(Val_2_1_3))) ∧ ((¬(Val_2_2_1)) ∨ (¬(Val_2_2_2))) ∧ ((¬(Val_2_2_1)) ∨ (¬(Val_2_2_3))) ∧ ((¬(Val_2_2_2)) ∨ (¬(Val_2_2_3))) ∧ ((¬(Val_2_3_1)) ∨ (¬(Val_2_3_2))) ∧ ((¬(Val_2_3_1)) ∨ (¬(Val_2_3_3))) ∧ ((¬(Val_2_3_2)) ∨ (¬(Val_2_3_3))) ∧ ((¬(Val_3_1_1)) ∨ (¬(Val_3_1_2))) ∧ ((¬(Val_3_1_1)) ∨ (¬(Val_3_1_3))) ∧ ((¬(Val_3_1_2)) ∨ (¬(Val_3_1_3))) ∧ ((¬(Val_3_2_1)) ∨ (¬(Val_3_2_2))) ∧ ((¬(Val_3_2_1)) ∨ (¬(Val_3_2_3))) ∧ ((¬(Val_3_2_2)) ∨ (¬(Val_3_2_3))) ∧ ((¬(Val_3_3_1)) ∨ (¬(Val_3_3_2))) ∧ ((¬(Val_3_3_1)) ∨ (¬(Val_3_3_3))) ∧ ((¬(Val_3_3_2)) ∨ (¬(Val_3_3_3)))
# Clause 002: ((¬(Val_1_1_1)) ∨ (¬(Val_1_2_1))) ∧ ((¬(Val_1_1_1)) ∨ (¬(Val_1_3_1))) ∧ ((¬(Val_1_2_1)) ∨ (¬(Val_1_3_1))) ∧ ((¬(Val_1_1_2)) ∨ (¬(Val_1_2_2))) ∧ ((¬(Val_1_1_2)) ∨ (¬(Val_1_3_2))) ∧ ((¬(Val_1_2_2)) ∨ (¬(Val_1_3_2))) ∧ ((¬(Val_1_1_3)) ∨ (¬(Val_1_2_3))) ∧ ((¬(Val_1_1_3)) ∨ (¬(Val_1_3_3))) ∧ ((¬(Val_1_2_3)) ∨ (¬(Val_1_3_3))) ∧ ((¬(Val_2_1_1)) ∨ (¬(Val_2_2_1))) ∧ ((¬(Val_2_1_1)) ∨ (¬(Val_2_3_1))) ∧ ((¬(Val_2_2_1)) ∨ (¬(Val_2_3_1))) ∧ ((¬(Val_2_1_2)) ∨ (¬(Val_2_2_2))) ∧ ((¬(Val_2_1_2)) ∨ (¬(Val_2_3_2))) ∧ ((¬(Val_2_2_2)) ∨ (¬(Val_2_3_2))) ∧ ((¬(Val_2_1_3)) ∨ (¬(Val_2_2_3))) ∧ ((¬(Val_2_1_3)) ∨ (¬(Val_2_3_3))) ∧ ((¬(Val_2_2_3)) ∨ (¬(Val_2_3_3))) ∧ ((¬(Val_3_1_1)) ∨ (¬(Val_3_2_1))) ∧ ((¬(Val_3_1_1)) ∨ (¬(Val_3_3_1))) ∧ ((¬(Val_3_2_1)) ∨ (¬(Val_3_3_1))) ∧ ((¬(Val_3_1_2)) ∨ (¬(Val_3_2_2))) ∧ ((¬(Val_3_1_2)) ∨ (¬(Val_3_3_2))) ∧ ((¬(Val_3_2_2)) ∨ (¬(Val_3_3_2))) ∧ ((¬(Val_3_1_3)) ∨ (¬(Val_3_2_3))) ∧ ((¬(Val_3_1_3)) ∨ (¬(Val_3_3_3))) ∧ ((¬(Val_3_2_3)) ∨ (¬(Val_3_3_3)))
# Clause 003: ((¬(Val_1_1_1)) ∨ (¬(Val_2_1_1))) ∧ ((¬(Val_1_1_1)) ∨ (¬(Val_3_1_1))) ∧ ((¬(Val_2_1_1)) ∨ (¬(Val_3_1_1))) ∧ ((¬(Val_1_1_2)) ∨ (¬(Val_2_1_2))) ∧ ((¬(Val_1_1_2)) ∨ (¬(Val_3_1_2))) ∧ ((¬(Val_2_1_2)) ∨ (¬(Val_3_1_2))) ∧ ((¬(Val_1_1_3)) ∨ (¬(Val_2_1_3))) ∧ ((¬(Val_1_1_3)) ∨ (¬(Val_3_1_3))) ∧ ((¬(Val_2_1_3)) ∨ (¬(Val_3_1_3))) ∧ ((¬(Val_1_2_1)) ∨ (¬(Val_2_2_1))) ∧ ((¬(Val_1_2_1)) ∨ (¬(Val_3_2_1))) ∧ ((¬(Val_2_2_1)) ∨ (¬(Val_3_2_1))) ∧ ((¬(Val_1_2_2)) ∨ (¬(Val_2_2_2))) ∧ ((¬(Val_1_2_2)) ∨ (¬(Val_3_2_2))) ∧ ((¬(Val_2_2_2)) ∨ (¬(Val_3_2_2))) ∧ ((¬(Val_1_2_3)) ∨ (¬(Val_2_2_3))) ∧ ((¬(Val_1_2_3)) ∨ (¬(Val_3_2_3))) ∧ ((¬(Val_2_2_3)) ∨ (¬(Val_3_2_3))) ∧ ((¬(Val_1_3_1)) ∨ (¬(Val_2_3_1))) ∧ ((¬(Val_1_3_1)) ∨ (¬(Val_3_3_1))) ∧ ((¬(Val_2_3_1)) ∨ (¬(Val_3_3_1))) ∧ ((¬(Val_1_3_2)) ∨ (¬(Val_2_3_2))) ∧ ((¬(Val_1_3_2)) ∨ (¬(Val_3_3_2))) ∧ ((¬(Val_2_3_2)) ∨ (¬(Val_3_3_2))) ∧ ((¬(Val_1_3_3)) ∨ (¬(Val_2_3_3))) ∧ ((¬(Val_1_3_3)) ∨ (¬(Val_3_3_3))) ∧ ((¬(Val_2_3_3)) ∨ (¬(Val_3_3_3)))
# Clause 004: Given_1_2_2
# Clause 005: ((¬(Given_1_2_2)) ∨ (Val_1_2_2))
# Clause 006: LessH_1_1
# Clause 007: ((¬(LessH_1_1)) ∨ (¬(Val_1_1_1)) ∨ (¬(Val_1_2_1))) ∧ ((¬(LessH_1_1)) ∨ (¬(Val_1_1_2)) ∨ (¬(Val_1_2_1))) ∧ ((¬(LessH_1_1)) ∨ (¬(Val_1_1_2)) ∨ (¬(Val_1_2_2))) ∧ ((¬(LessH_1_1)) ∨ (¬(Val_1_1_3)) ∨ (¬(Val_1_2_1))) ∧ ((¬(LessH_1_1)) ∨ (¬(Val_1_1_3)) ∨ (¬(Val_1_2_2))) ∧ ((¬(LessH_1_1)) ∨ (¬(Val_1_1_3)) ∨ (¬(Val_1_2_3)))
# Clause 008: GreaterV_1_2
# Clause 009: GreaterV_2_1
# Clause 010: ((¬(GreaterV_1_2)) ∨ (¬(Val_1_2_1)) ∨ (¬(Val_2_2_1))) ∧ ((¬(GreaterV_1_2)) ∨ (¬(Val_1_2_1)) ∨ (¬(Val_2_2_2))) ∧ ((¬(GreaterV_1_2)) ∨ (¬(Val_1_2_1)) ∨ (¬(Val_2_2_3))) ∧ ((¬(GreaterV_1_2)) ∨ (¬(Val_1_2_2)) ∨ (¬(Val_2_2_2))) ∧ ((¬(GreaterV_1_2)) ∨ (¬(Val_1_2_2)) ∨ (¬(Val_2_2_3))) ∧ ((¬(GreaterV_1_2)) ∨ (¬(Val_1_2_3)) ∨ (¬(Val_2_2_3))) ∧ ((¬(GreaterV_2_1)) ∨ (¬(Val_2_1_1)) ∨ (¬(Val_3_1_1))) ∧ ((¬(GreaterV_2_1)) ∨ (¬(Val_2_1_1)) ∨ (¬(Val_3_1_2))) ∧ ((¬(GreaterV_2_1)) ∨ (¬(Val_2_1_1)) ∨ (¬(Val_3_1_3))) ∧ ((¬(GreaterV_2_1)) ∨ (¬(Val_2_1_2)) ∨ (¬(Val_3_1_2))) ∧ ((¬(GreaterV_2_1)) ∨ (¬(Val_2_1_2)) ∨ (¬(Val_3_1_3))) ∧ ((¬(GreaterV_2_1)) ∨ (¬(Val_2_1_3)) ∨ (¬(Val_3_1_3)))
# ========================= END KB DEBUG =========================

# %% [markdown]
# # Backward chaining

# %%
kb = build_kb(data)

res = query_val(kb, i=1, j=1, N=data.n)
print(res)
# Out:
# [1]

# %% [markdown]
# # Benchmark

# %%
# ===== FIX PATH =====
sys.path.append(os.getcwd())

os.makedirs("output/benchmark_result", exist_ok=True)

# ===== LOOP INPUT =====
for i in range(8, 9):
    input_file = f"input/input_{i:02}.txt"

    if not os.path.exists(input_file):
        print(f"Skip {input_file}")
        continue

    print(f"\n=== Running {input_file} ===")

    # ===== CHẠY BENCHMARK =====
    df = benchmark_one(input_file)

    # ===== FILE RIÊNG =====
    output_file = f"output/benchmark_result/benchmark_{i:02}.csv"

    df.to_csv(output_file, index=False)

    print(f"✅ Saved {input_file} → {output_file}")
# Out:
# === Running input/input_08.txt ===
#
# ===== Running input/input_08.txt =====
# → Forward Chaining
# → A* (Heuristic 1)
# → A* (Heuristic 2)
# → Brute Force
# → Backtracking
# ✅ Saved input/input_08.txt → output/benchmark_result/benchmark_08.csv
